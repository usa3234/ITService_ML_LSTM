# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('itService_day.xlsx')
df['RQST_DT'] = df['RQST_DT'].astype(str)
df['RQST_DT'] = pd.to_datetime(df['RQST_DT'])
df.rename(columns = {'RQST_DT' : 'YYMM'}, inplace = True)
df
# Out:
#            YYMM  CNT
# 0    2014-01-02    5
# 1    2014-01-03    4
# 2    2014-01-06    8
# 3    2014-01-07    6
# 4    2014-01-08    2
# ...         ...  ...
# 1731 2021-12-24    2
# 1732 2021-12-28    6
# 1733 2021-12-29    3
# 1734 2021-12-30    5
# 1735 2021-12-31    3
#
# [1736 rows x 2 columns]

# %%
# 입력데이터
feature_df = df[['YYMM']]
## 정답데이터
label_df = df[['CNT']]

print(feature_df.shape, label_df.shape)
# Out:
# (1736, 1) (1736, 1)

# %%
# 모델을 만듭니다.
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
feature_num = np.array(feature_df).astype('float32')
label_num = np.array(label_df)

# %%
# 모델을 학습시킵니다. 
model.fit(feature_num, label_num, epochs=700)
# Out:
# Epoch 1/700
# 55/55 [==============================] - 0s 482us/step - loss: inf
# Epoch 2/700
# 55/55 [==============================] - 0s 482us/step - loss: inf
# Epoch 3/700
# 55/55 [==============================] - 0s 482us/step - loss: inf
# Epoch 4/700
# 55/55 [==============================] - 0s 463us/step - loss: inf
# Epoch 5/700
# 55/55 [==============================] - 0s 445us/step - loss: inf
# Epoch 6/700
# 55/55 [==============================] - 0s 463us/step - loss: inf
# Epoch 7/700
# 55/55 [==============================] - 0s 445us/step - loss: inf
# Epoch 8/700
# 55/55 [==============================] - 0s 445us/step - loss: inf
# Epoch 9/700
# 55/55 [==============================] - 0s 463us/step - loss: inf
# Epoch 10/700
# 55/55 [==============================] - 0s 463us/step - loss: inf
# Epoch 11/700
# 55/55 [==============================] - 0s 445us/step - loss: inf
# Epoch 12/700
# 55/55 [==============================] - 0s 445us/step - loss: inf
# ...

# %%
feature_df
# Out:
#            YYMM
# 0    2014-01-02
# 1    2014-01-03
# 2    2014-01-06
# 3    2014-01-07
# 4    2014-01-08
# ...         ...
# 1731 2021-12-24
# 1732 2021-12-28
# 1733 2021-12-29
# 1734 2021-12-30
# 1735 2021-12-31
#
# [1736 rows x 1 columns]

# %%
start_date = pd.to_datetime('2022-01-01') ## 시작 날짜
end_date = pd.to_datetime('2022-01-31') ## 마지막 날짜
 
dates = pd.date_range(start_date,end_date,freq='D') ## 일단위로 생성
month_df = pd.DataFrame(dates)

month_df.rename(columns={0 : 'YYMM'}, inplace=True)
month_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YYMM    31 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 376.0 bytes

# %%
#student_card = pd.DataFrame({'YYMM':['2022-01-24']})
#student_card['YYMM'] = pd.to_datetime(df['YYMM'])
pre_feature_num = np.array(month_df).astype('float32')
print(model.predict(pre_feature_num))
# Out:
# [[1.4039605e+18]
#  [1.4040343e+18]
#  [1.4041082e+18]
#  [1.4041820e+18]
#  [1.4042560e+18]
#  [1.4043301e+18]
#  [1.4044039e+18]
#  [1.4044778e+18]
#  [1.4045518e+18]
#  [1.4046256e+18]
#  [1.4046996e+18]
#  [1.4047736e+18]
#  [1.4048474e+18]
#  [1.4049213e+18]
#  [1.4049953e+18]
#  [1.4050692e+18]
#  [1.4051431e+18]
#  [1.4052170e+18]
#  [1.4052909e+18]
#  [1.4053648e+18]
#  [1.4054388e+18]
#  [1.4055127e+18]
#  [1.4055867e+18]
#  [1.4056605e+18]
#  [1.4057344e+18]
#  [1.4058084e+18]
#  [1.4058823e+18]
#  [1.4059562e+18]
#  [1.4060302e+18]
#  [1.4061040e+18]
#  [1.4061779e+18]]
